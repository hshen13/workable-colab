# %% [markdown]
# <a href="https://colab.research.google.com/github/hshen13/workable-colab/blob/main/text2video_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/FareedKhan-dev/train-text2video-scratch.git
# %cd train-text2video-scratch
# Out:
# Cloning into 'train-text2video-scratch'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 66 (delta 13), reused 52 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (66/66), 6.19 MiB | 44.34 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/train-text2video-scratch

# %%
# %cd train-text2video-scratch
# !pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: 'train-text2video-scratch'
# /content/train-text2video-scratch
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# ...

# %%
# !python train.py

# %%
# !python /content/train-text2video-scratch/data_generation/msrvtt.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing Videos:  14%|█████▊                                   | 920/6513 [01:27<08:12, 11.36it/s]
# t:   0% 0/46 [00:00<?, ?it/s, now=None]
# MoviePy - - File ready: ../training_data/video1827.gif.
# Processing Videos:  14%|█████▊                                   | 920/6513 [01:27<08:12, 11.36it/s]Converted ./msrvtt_data/msrvtt/TrainValVideo/video1827.mp4 to GIF and saved as ../training_data/video1827.gif
# MoviePy - Building file  ../training_data/video1828.gif
# MoviePy - - Generating GIF frames.
# Processing Videos:  14%|█████▊                                   | 922/6513 [01:27<08:00, 11.64it/s]
# t:   0% 0/29 [00:00<?, ?it/s, now=None]
# MoviePy - - File ready: ../training_data/video1828.gif.
# Processing Videos:  14%|█████▊                                   | 922/6513 [01:27<08:00, 11.64it/s]Converted ./msrvtt_data/msrvtt/TrainValVideo/video1828.mp4 to GIF and saved as ../training_data/video1828.gif
# ...

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 1: 0.8692137002944946
# 2: 0.863520622253418
# 3: 0.8663874864578247
# 4: 0.8670812249183655
# 5: 0.876365602016449
# 6: 0.8625033497810364
# 7: 0.8580535650253296
# 8: 0.8610782027244568
# 9: 0.8576478362083435
# 10: 0.8706880211830139
# 11: 0.8589015007019043
# 12: 0.8690211176872253
# 13: 0.862373411655426
# 14: 0.8649452924728394
# 15: 0.8538534045219421
# 16: 0.8620671033859253
# 17: 0.8568851947784424
# 18: 0.8572554588317871
# 19: 0.8593719005584717
# 20: 0.8628228902816772
# 21: 0.8653838634490967
# 22: 0.8610755205154419
# 23: 0.84972083568573
# 24: 0.863860011100769
# 25: 0.8584283590316772
# 26: 0.8593782186508179
# 27: 0.8672774434089661
# 28: 0.8684031963348389
# 29: 0.8651091456413269
# 30: 0.8611872792243958
# 31: 0.8639699816703796
# 32: 0.8563536405563354
# 33: 0.8721225261688232
# 34: 0.8550686240196228
# 35: 0.8682054877281189
# 36: 0.8710378408432007
# 37: 0.865949809551239
# 38: 0.8703753352165222
# ...

# %%
# !python generate.py --text "A cat is dancing"
# Out:
# 2025-02-11 20:32:55.402617: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-11 20:32:55.420957: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739305975.443235  679923 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739305975.449958  679923 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
