# %% [markdown]
# <a href="https://colab.research.google.com/github/hshen13/workable-colab/blob/main/controlnettest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision diffusers transformers accelerate opencv-python numpy matplotlib tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (0.32.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.3.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers) (8.6.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.5.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2025.1.31)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt

# 检查 GPU 是否可用
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

# %%
import os
from torch.utils.data import Dataset, DataLoader

# 请修改data_dir为您的数据所在路径
data_dir = "/content/data"  # 假设数据位于此路径下
images_dir = os.path.join(data_dir, "images")
skeletons_dir = os.path.join(data_dir, "skeletons")

# 获取所有图像文件名列表（假定骨骼图与原图文件名前缀相同）
image_files = sorted([f for f in os.listdir(images_dir) if f.endswith(".png") or f.endswith(".jpg")])
skeleton_files = sorted([f for f in os.listdir(skeletons_dir) if f.endswith(".png") or f.endswith(".jpg")])

print(f"找到 {len(image_files)} 张原图, {len(skeleton_files)} 张骨骼图.")

# 定义图像分辨率
img_size = 128  # 可以调整，如 256

class PoseDataset(Dataset):
    def __len__(self):
        return min(len(image_files), len(skeleton_files))

    def __getitem__(self, idx):
        # 构建文件路径
        img_path = os.path.join(images_dir, image_files[idx])
        skel_path = os.path.join(skeletons_dir, skeleton_files[idx])

        # 读取原始图像 (BGR格式)，转换为RGB
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # 读取骨骼图 (灰度)
        skel = cv2.imread(skel_path, cv2.IMREAD_GRAYSCALE)

        # 调整大小到统一尺寸
        if img_size is not None:
            img = cv2.resize(img, (img_size, img_size))
            skel = cv2.resize(skel, (img_size, img_size))

        # 转换为浮点，并归一化到[-1, 1]
        img = img.astype(np.float32) / 127.5 - 1.0  # 原图3通道
        skel = skel.astype(np.float32) / 127.5 - 1.0  # 骨骼图1通道

        # 将数据转换为PyTorch张量，并调整维度顺序为 [C, H, W]
        img_tensor = torch.from_numpy(img).permute(2, 0, 1)  # [3, H, W]
        skel_tensor = torch.from_numpy(skel).unsqueeze(0)    # [1, H, W]

        return skel_tensor, img_tensor

# 创建数据集和数据加载器
dataset = PoseDataset()
batch_size = 8  # 可根据显存大小调整
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)

# 打印一个样本以验证
skel_sample, img_sample = dataset[0]
print("骨骼张量形状:", skel_sample.shape, "原图张量形状:", img_sample.shape)
print("骨骼张量值范围:", skel_sample.min().item(), "~", skel_sample.max().item())

# %%
from diffusers import UNet2DModel

# 定义UNet模型
model = UNet2DModel(
    sample_size=img_size,       # 输入图像大小 (H=img_size, W=img_size)
    in_channels=4,              # 输入通道: 3 (图像) + 1 (骨骼)
    out_channels=3,             # 输出通道: 3 (图像)
    layers_per_block=2,         # 每个下采样/上采样块的层数
    block_out_channels=(64, 128, 128, 256),  # 每个下采样块的通道数
    down_block_types=(         # 下采样模块类型
        "DownBlock2D",         # 无注意力的下采样块
        "DownBlock2D",
        "DownBlock2D",
        "DownBlock2D",
    ),
    up_block_types=(           # 上采样模块类型
        "UpBlock2D",           # 无注意力的上采样块
        "UpBlock2D",
        "UpBlock2D",
        "UpBlock2D",
    )
)
model.to(device)
print(f"Model parameters: {sum(p.numel() for p in model.parameters())}")

# %%
import torch.nn.functional as F

# 扩散过程超参数
num_timesteps = 1000  # 扩散步数 T
beta_start, beta_end = 1e-4, 0.02  # beta调度（线性）
betas = torch.linspace(beta_start, beta_end, num_timesteps).to(device)
alphas = 1.0 - betas
alpha_prod = torch.cumprod(alphas, dim=0)  # 计算 \bar{α}_t 累乘
alpha_prod_prev = torch.cat([torch.tensor([1.0]).to(device), alpha_prod[:-1]], dim=0)

# 优化器
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# 训练设置
num_epochs = 5   # 训练轮数 (根据数据集大小和需求调整)
log_interval = 100  # 每隔多少步打印一次loss
sample_interval = 1  # 每隔多少轮生成示例图像

# 开始训练循环
model.train()
for epoch in range(1, num_epochs+1):
    epoch_loss = 0.0
    for step, (skel_batch, img_batch) in enumerate(dataloader):
        # 将批数据移动到GPU
        skel_batch = skel_batch.to(device)   # [B, 1, H, W]
        img_batch = img_batch.to(device)     # [B, 3, H, W]

        # 从均匀分布随机采样一个时间步 t，对于一个batch每个样本可以用不同t
        t = torch.randint(0, num_timesteps, (batch_size,), device=device)

        # 采样与img_batch形状相同的标准正态噪声
        noise = torch.randn_like(img_batch)
        # 计算 \sqrt{\bar{α}_t} 和 \sqrt{1-\bar{α}_t} （需将 alpha_prod 按t索引并调整维度）
        alpha_prod_t = alpha_prod[t].reshape(-1, 1, 1, 1)        # [B,1,1,1]
        sqrt_alpha_prod_t = torch.sqrt(alpha_prod_t)            # \sqrt{\bar{\alpha}_t}
        sqrt_one_minus_alpha_prod_t = torch.sqrt(1 - alpha_prod_t)  # \sqrt{1-\bar{\alpha}_t}

        # 前向扩散：生成 x_t
        x_t = sqrt_alpha_prod_t * img_batch + sqrt_one_minus_alpha_prod_t * noise

        # 将骨骼条件与带噪图像拼接作为模型输入
        model_in = torch.cat([x_t, skel_batch], dim=1)  # [B, 4, H, W]

        # 模型预测噪声
        model_output = model(model_in, timesteps=t).sample  # diffusers模型输出包含在sample属性中
        pred_noise = model_output  # [B, 3, H, W]

        # 计算MSE损失 (预测噪声 vs 实际噪声)
        loss = F.mse_loss(pred_noise, noise)
        epoch_loss += loss.item()

        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 打印训练信息
        if (step + 1) % log_interval == 0:
            print(f"Epoch {epoch} Step {step+1}/{len(dataloader)}, Loss: {loss.item():.4f}")

    avg_loss = epoch_loss / len(dataloader)
    print(f"Epoch {epoch} completed, average loss: {avg_loss:.4f}")

    # 每隔 sample_interval 轮次，生成样本进行可视化
    if epoch % sample_interval == 0:
        model.eval()
        with torch.no_grad():
            # 从当前训练集中取一张骨骼图来测试
            test_skel, test_img = dataset[0]  # 取第一个样本为例
            test_skel = test_skel.unsqueeze(0).to(device)  # [1,1,H,W]
            true_img = test_img.numpy().transpose(1,2,0)   # 转回numpy用于展示 (H,W,C)
            true_img = ((true_img + 1) * 127.5).astype(np.uint8)  # 反归一化到[0,255]

            # 执行扩散采样过程（从纯噪声生成图像）
            # 从标准正态噪声开始 (B=1)
            x = torch.randn((1, 3, img_size, img_size), device=device)
            for ti in range(num_timesteps-1, -1, -1):
                # 当前步的alpha和beta
                alpha_t = alphas[ti]
                alpha_prod_t = alpha_prod[ti]
                alpha_prod_prev_t = alpha_prod_prev[ti]
                beta_t = betas[ti]
                # 模型预测噪声
                model_in = torch.cat([x, test_skel], dim=1)  # 拼接骨骼条件
                model_out = model(model_in, timesteps=torch.tensor([ti]).to(device)).sample
                pred_noise = model_out[0]  # 输出维度 [1,3,H,W],取第0个

                # 计算x_{t-1}的预测（DDPM采样公式）
                # μ_theta = 1/sqrt(alpha_t) * (x_t - (1-alpha_t)/sqrt(1-ᾱ_t) * pred_noise)
                sqrt_recip_alpha_t = torch.sqrt(1.0/alpha_t)
                sqrt_one_minus_alpha_prod_t = torch.sqrt(1 - alpha_prod_t)
                mu = sqrt_recip_alpha_t * (x - (beta_t / sqrt_one_minus_alpha_prod_t) * pred_noise)
                if ti > 0:
                    # 添加随机噪声
                    sigma_t = torch.sqrt((1 - alpha_prod_prev_t) / (1 - alpha_prod_t) * beta_t)
                    noise_t = torch.randn_like(x)
                    x = mu + sigma_t * noise_t
                else:
                    x = mu
                # 为数值稳定，裁剪x到[-1,1]
                x = x.clamp(-1, 1)

            # 获得生成的图像
            gen_img = x.cpu().numpy()[0].transpose(1, 2, 0)  # 转为numpy (H,W,C)
            gen_img = ((gen_img + 1) * 127.5).astype(np.uint8)  # 反归一化为0-255

            # 显示原图与生成图对比
            fig, axes = plt.subplots(1, 2, figsize=(6,3))
            axes[0].imshow(true_img)
            axes[0].set_title("真实图像")
            axes[0].axis('off')
            axes[1].imshow(gen_img)
            axes[1].set_title("生成图像")
            axes[1].axis('off')
            plt.show()
        model.train()

# %%
# 定义生成函数
def generate_image_from_skeleton(skeleton_img):
    """ 给定骨骼图（numpy二维数组或张量），生成对应的图像（numpy数组）。 """
    model.eval()
    with torch.no_grad():
        # 确保骨骼图为numpy数组
        if isinstance(skeleton_img, torch.Tensor):
            skel = skeleton_img.cpu().numpy()
        else:
            skel = skeleton_img
        # 如果是二维，则添加批次和通道维度
        if skel.ndim == 2:
            skel = skel[None, None, ...]  # [1,1,H,W]
        elif skel.ndim == 3:
            skel = skel[None, ...]        # [1,1,H,W] if it was [H,W,1]
        skel = torch.from_numpy(skel.astype(np.float32)).to(device)

        # 初始噪声图 x_T
        x = torch.randn((1, 3, skel.shape[-2], skel.shape[-1]), device=device)
        # 反向扩散过程
        for ti in range(num_timesteps-1, -1, -1):
            alpha_t = alphas[ti]
            alpha_prod_t = alpha_prod[ti]
            alpha_prod_prev_t = alpha_prod_prev[ti]
            beta_t = betas[ti]
            # 模型预测噪声
            model_in = torch.cat([x, skel], dim=1)
            pred = model(model_in, timesteps=torch.tensor([ti]).to(device)).sample
            pred_noise = pred[0]
            # 计算均值 mu_t
            sqrt_recip_alpha_t = (1.0/alpha_t).sqrt()
            sqrt_one_minus_alpha_prod_t = (1 - alpha_prod_t).sqrt()
            mu = sqrt_recip_alpha_t * (x - (beta_t / sqrt_one_minus_alpha_prod_t) * pred_noise)
            if ti > 0:
                sigma_t = ((1 - alpha_prod_prev_t)/(1 - alpha_prod_t) * beta_t).sqrt()
                x = mu + sigma_t * torch.randn_like(x)
            else:
                x = mu
            x = x.clamp(-1, 1)
        # 转换输出图像为numpy格式
        result = x.cpu().numpy()[0].transpose(1, 2, 0)  # [H,W,C]
        result = ((result + 1) * 127.5).astype(np.uint8)  # 反归一化
        return result

# 测试生成函数：用训练集第一张骨骼图
test_skel_img = dataset[0][0].numpy().squeeze()  # 取出骨骼图的numpy数组 [H,W]
gen_result = generate_image_from_skeleton(test_skel_img)
print("生成图像尺寸:", gen_result.shape)
plt.imshow(gen_result)
plt.title("生成结果示例")
plt.axis('off')
plt.show()

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: fineGrained).
# The token `456` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `456`

# %%
# 安装最新版本依赖
# !pip install --upgrade diffusers transformers accelerate opencv-python

import torch
from PIL import Image
from diffusers import StableDiffusionXLControlNetPipeline, ControlNetModel

# 设置设备（建议使用 GPU）
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 加载 SDXL 兼容的 ControlNet 模型（请确认仓库名称是否正确）
controlnet = ControlNetModel.from_pretrained("thibaud/controlnet-openpose-sdxl-1.0", torch_dtype=torch.float16)
controlnet.to(device)

# 加载 SDXL + ControlNet 管道
pipe = StableDiffusionXLControlNetPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",  # SDXL 模型
    controlnet=controlnet,
    torch_dtype=torch.float16
)
pipe.to(device)

# 加载原图和目标骨架图（确保图片尺寸与模型要求一致，必要时进行预处理）
source_image = Image.open("/content/ManofSteel.png").convert("RGB")
target_skeleton = Image.open("/content/139.png").convert("RGB")

prompt = "superman"
strength = 0.9  # 控制骨架条件对生成结果的影响力度

# 使用 image-to-image 模式生成新图
result = pipe(prompt=prompt, image=source_image, control_image=target_skeleton, strength=strength).images[0]
result.show()
result.save("generated_result_sdxl.png")
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (0.32.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.49.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers) (8.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from diffusers) (3.17.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.5.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers) (11.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.5.1+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.2->diffusers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# An error occurred while trying to fetch thibaud/controlnet-openpose-sdxl-1.0: thibaud/controlnet-openpose-sdxl-1.0 does not appear to have a file named diffusion_pytorch_model.safetensors.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#@title 1. 安装依赖 & 克隆仓库
# 安装最新依赖，确保使用安全加载格式
# !pip install --upgrade diffusers transformers accelerate opencv-python safetensors

# 克隆 ControlNetPlus 仓库
# !git clone https://github.com/xinsir6/ControlNetPlus.git

# 如果仓库内有 requirements.txt，也可以安装其依赖：
# !pip install -r ControlNetPlus/requirements.txt
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (0.32.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.49.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (0.5.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers) (8.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from diffusers) (3.17.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers) (11.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.5.1+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.2->diffusers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Cloning into 'ControlNetPlus'...
# remote: Enumerating objects: 339, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 339 (delta 30), reused 28 (delta 17), pack-reused 288 (from 1)
# Receiving objects: 100% (339/339), 46.87 MiB | 67.03 MiB/s, done.
# Resolving deltas: 100% (123/123), done.
# Collecting absl-py==2.1.0 (from -r ControlNetPlus/requirements.txt (line 1))
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting accelerate==0.28.0 (from -r ControlNetPlus/requirements.txt (line 2))
#   Downloading accelerate-0.28.0-py3-none-any.whl.metadata (18 kB)
# Collecting aiofiles==23.2.1 (from -r ControlNetPlus/requirements.txt (line 3))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting aiohttp==3.9.3 (from -r ControlNetPlus/requirements.txt (line 4))
#   Downloading aiohttp-3.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting aiosignal==1.3.1 (from -r ControlNetPlus/requirements.txt (line 5))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting albumentations==1.4.2 (from -r ControlNetPlus/requirements.txt (line 6))
#   Downloading albumentations-1.4.2-py3-none-any.whl.metadata (36 kB)
# Collecting altair==5.3.0 (from -r ControlNetPlus/requirements.txt (line 7))
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting annotated-types==0.6.0 (from -r ControlNetPlus/requirements.txt (line 8))
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting antlr4-python3-runtime==4.9.3 (from -r ControlNetPlus/requirements.txt (line 9))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting anyio==4.3.0 (from -r ControlNetPlus/requirements.txt (line 10))
#   Downloading anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting appdirs==1.4.4 (from -r ControlNetPlus/requirements.txt (line 11))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: argon2-cffi==23.1.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 12)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 13)) (21.2.0)
# Collecting arrow==1.3.0 (from -r ControlNetPlus/requirements.txt (line 14))
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting asttokens==2.4.1 (from -r ControlNetPlus/requirements.txt (line 15))
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting async-lru==2.0.4 (from -r ControlNetPlus/requirements.txt (line 16))
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting async-timeout==4.0.3 (from -r ControlNetPlus/requirements.txt (line 17))
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting attrs==23.2.0 (from -r ControlNetPlus/requirements.txt (line 18))
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting Babel==2.14.0 (from -r ControlNetPlus/requirements.txt (line 19))
#   Downloading Babel-2.14.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 20)) (0.2.0)
# Collecting beautifulsoup4==4.12.3 (from -r ControlNetPlus/requirements.txt (line 21))
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach==6.1.0 (from -r ControlNetPlus/requirements.txt (line 22))
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting cachetools==5.3.3 (from -r ControlNetPlus/requirements.txt (line 23))
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting certifi==2024.2.2 (from -r ControlNetPlus/requirements.txt (line 24))
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi==1.16.0 (from -r ControlNetPlus/requirements.txt (line 25))
#   Downloading cffi-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting charset-normalizer==3.3.2 (from -r ControlNetPlus/requirements.txt (line 26))
#   Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting click==8.1.7 (from -r ControlNetPlus/requirements.txt (line 27))
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cmake==3.29.0.1 (from -r ControlNetPlus/requirements.txt (line 28))
#   Downloading cmake-3.29.0.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Collecting comm==0.2.2 (from -r ControlNetPlus/requirements.txt (line 29))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting contourpy==1.1.1 (from -r ControlNetPlus/requirements.txt (line 30))
#   Downloading contourpy-1.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting controlnet-aux==0.0.9 (from -r ControlNetPlus/requirements.txt (line 31))
#   Downloading controlnet_aux-0.0.9-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 32)) (0.12.1)
# Collecting dadaptation==3.2 (from -r ControlNetPlus/requirements.txt (line 33))
#   Downloading dadaptation-3.2.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting datasets==2.18.0 (from -r ControlNetPlus/requirements.txt (line 34))
#   Downloading datasets-2.18.0-py3-none-any.whl.metadata (20 kB)
# Collecting debugpy==1.8.1 (from -r ControlNetPlus/requirements.txt (line 35))
#   Downloading debugpy-1.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r ControlNetPlus/requirements.txt (line 36))
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting deepspeed==0.14.0 (from -r ControlNetPlus/requirements.txt (line 37))
#   Downloading deepspeed-0.14.0.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 38)) (0.7.1)
# Collecting diffusers==0.27.2 (from -r ControlNetPlus/requirements.txt (line 39))
#   Downloading diffusers-0.27.2-py3-none-any.whl.metadata (18 kB)
# Collecting dill==0.3.8 (from -r ControlNetPlus/requirements.txt (line 40))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: docker-pycreds==0.4.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 41)) (0.4.0)
# Collecting einops==0.7.0 (from -r ControlNetPlus/requirements.txt (line 42))
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting exceptiongroup==1.2.0 (from -r ControlNetPlus/requirements.txt (line 43))
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting executing==2.0.1 (from -r ControlNetPlus/requirements.txt (line 44))
#   Downloading executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting fastapi==0.110.2 (from -r ControlNetPlus/requirements.txt (line 45))
#   Downloading fastapi-0.110.2-py3-none-any.whl.metadata (24 kB)
# Collecting fastjsonschema==2.19.1 (from -r ControlNetPlus/requirements.txt (line 46))
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting ffmpy==0.3.2 (from -r ControlNetPlus/requirements.txt (line 47))
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting filelock==3.13.3 (from -r ControlNetPlus/requirements.txt (line 48))
#   Downloading filelock-3.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting fonttools==4.51.0 (from -r ControlNetPlus/requirements.txt (line 49))
#   Downloading fonttools-4.51.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 14.1 MB/s eta 0:00:00
# Collecting fqdn==1.5.1 (from -r ControlNetPlus/requirements.txt (line 50))
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting frozenlist==1.4.1 (from -r ControlNetPlus/requirements.txt (line 51))
#   Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting fsspec==2024.2.0 (from -r ControlNetPlus/requirements.txt (line 52))
#   Downloading fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting ftfy==6.2.0 (from -r ControlNetPlus/requirements.txt (line 53))
#   Downloading ftfy-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting gitdb==4.0.11 (from -r ControlNetPlus/requirements.txt (line 54))
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting GitPython==3.1.42 (from -r ControlNetPlus/requirements.txt (line 55))
#   Downloading GitPython-3.1.42-py3-none-any.whl.metadata (12 kB)
# Collecting google-auth==2.29.0 (from -r ControlNetPlus/requirements.txt (line 56))
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib==1.0.0 (from -r ControlNetPlus/requirements.txt (line 57))
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting gradio==3.41.2 (from -r ControlNetPlus/requirements.txt (line 58))
#   Downloading gradio-3.41.2-py3-none-any.whl.metadata (17 kB)
# Collecting gradio_client==0.5.0 (from -r ControlNetPlus/requirements.txt (line 59))
#   Downloading gradio_client-0.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting grpcio==1.62.1 (from -r ControlNetPlus/requirements.txt (line 60))
#   Downloading grpcio-1.62.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: h11==0.14.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 61)) (0.14.0)
# Collecting hjson==3.1.0 (from -r ControlNetPlus/requirements.txt (line 62))
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting httpcore==1.0.5 (from -r ControlNetPlus/requirements.txt (line 63))
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting httpx==0.27.0 (from -r ControlNetPlus/requirements.txt (line 64))
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting huggingface-hub==0.22.1 (from -r ControlNetPlus/requirements.txt (line 65))
#   Downloading huggingface_hub-0.22.1-py3-none-any.whl.metadata (12 kB)
# Collecting idna==3.6 (from -r ControlNetPlus/requirements.txt (line 66))
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting imageio==2.34.0 (from -r ControlNetPlus/requirements.txt (line 67))
#   Downloading imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting importlib_metadata==7.1.0 (from -r ControlNetPlus/requirements.txt (line 68))
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting importlib_resources==6.4.0 (from -r ControlNetPlus/requirements.txt (line 69))
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipykernel==6.29.4 (from -r ControlNetPlus/requirements.txt (line 70))
#   Downloading ipykernel-6.29.4-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.12.3 (from -r ControlNetPlus/requirements.txt (line 71))
#   Downloading ipython-8.12.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 72)) (0.2.0)
# Collecting ipywidgets==8.1.2 (from -r ControlNetPlus/requirements.txt (line 73))
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting isoduration==20.11.0 (from -r ControlNetPlus/requirements.txt (line 74))
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jedi==0.19.1 (from -r ControlNetPlus/requirements.txt (line 75))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting Jinja2==3.1.3 (from -r ControlNetPlus/requirements.txt (line 76))
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting joblib==1.3.2 (from -r ControlNetPlus/requirements.txt (line 77))
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting json5==0.9.24 (from -r ControlNetPlus/requirements.txt (line 78))
#   Downloading json5-0.9.24-py3-none-any.whl.metadata (30 kB)
# Collecting jsonpointer==2.4 (from -r ControlNetPlus/requirements.txt (line 79))
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting jsonschema==4.21.1 (from -r ControlNetPlus/requirements.txt (line 80))
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting jsonschema-specifications==2023.12.1 (from -r ControlNetPlus/requirements.txt (line 81))
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting jupyter==1.0.0 (from -r ControlNetPlus/requirements.txt (line 82))
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl.metadata (995 bytes)
# Collecting jupyter-console==6.6.3 (from -r ControlNetPlus/requirements.txt (line 83))
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-events==0.10.0 (from -r ControlNetPlus/requirements.txt (line 84))
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-lsp==2.2.4 (from -r ControlNetPlus/requirements.txt (line 85))
#   Downloading jupyter_lsp-2.2.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter_client==8.6.1 (from -r ControlNetPlus/requirements.txt (line 86))
#   Downloading jupyter_client-8.6.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter_core==5.7.2 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 87)) (5.7.2)
# Collecting jupyter_server==2.13.0 (from -r ControlNetPlus/requirements.txt (line 88))
#   Downloading jupyter_server-2.13.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyter_server_terminals==0.5.3 (from -r ControlNetPlus/requirements.txt (line 89))
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting jupyterlab==4.1.6 (from -r ControlNetPlus/requirements.txt (line 90))
#   Downloading jupyterlab-4.1.6-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 91)) (0.3.0)
# Collecting jupyterlab_server==2.26.0 (from -r ControlNetPlus/requirements.txt (line 92))
#   Downloading jupyterlab_server-2.26.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab_widgets==3.0.10 (from -r ControlNetPlus/requirements.txt (line 93))
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupytext==1.16.1 (from -r ControlNetPlus/requirements.txt (line 94))
#   Downloading jupytext-1.16.1-py3-none-any.whl.metadata (12 kB)
# Collecting kiwisolver==1.4.5 (from -r ControlNetPlus/requirements.txt (line 95))
#   Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting lazy_loader==0.3 (from -r ControlNetPlus/requirements.txt (line 96))
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting lightning-utilities==0.11.2 (from -r ControlNetPlus/requirements.txt (line 97))
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting lit==18.1.2 (from -r ControlNetPlus/requirements.txt (line 98))
#   Downloading lit-18.1.2.tar.gz (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.0/161.0 kB 15.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting loguru==0.7.2 (from -r ControlNetPlus/requirements.txt (line 99))
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Collecting Markdown==3.6 (from -r ControlNetPlus/requirements.txt (line 100))
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: markdown-it-py==3.0.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 101)) (3.0.0)
# Collecting MarkupSafe==2.1.5 (from -r ControlNetPlus/requirements.txt (line 102))
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting matplotlib==3.7.5 (from -r ControlNetPlus/requirements.txt (line 103))
#   Downloading matplotlib-3.7.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting matplotlib-inline==0.1.6 (from -r ControlNetPlus/requirements.txt (line 104))
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl.metadata (2.8 kB)
# Collecting mdit-py-plugins==0.4.0 (from -r ControlNetPlus/requirements.txt (line 105))
#   Downloading mdit_py_plugins-0.4.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: mdurl==0.1.2 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 106)) (0.1.2)
# Collecting mistune==3.0.2 (from -r ControlNetPlus/requirements.txt (line 107))
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 108)) (1.3.0)
# Collecting multidict==6.0.5 (from -r ControlNetPlus/requirements.txt (line 109))
#   Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting multiprocess==0.70.16 (from -r ControlNetPlus/requirements.txt (line 110))
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting nbclassic==1.0.0 (from -r ControlNetPlus/requirements.txt (line 111))
#   Downloading nbclassic-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting nbclient==0.10.0 (from -r ControlNetPlus/requirements.txt (line 112))
#   Downloading nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbconvert==7.16.3 (from -r ControlNetPlus/requirements.txt (line 113))
#   Downloading nbconvert-7.16.3-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: nbformat==5.10.4 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 114)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 115)) (1.6.0)
# Collecting networkx==3.1 (from -r ControlNetPlus/requirements.txt (line 116))
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting ninja==1.11.1.1 (from -r ControlNetPlus/requirements.txt (line 117))
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Collecting notebook==6.5.4 (from -r ControlNetPlus/requirements.txt (line 118))
#   Downloading notebook-6.5.4-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: notebook_shim==0.2.4 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 119)) (0.2.4)
# Collecting numpy==1.24.4 (from -r ControlNetPlus/requirements.txt (line 120))
#   Downloading numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from -r ControlNetPlus/requirements.txt (line 121))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from -r ControlNetPlus/requirements.txt (line 122))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from -r ControlNetPlus/requirements.txt (line 123))
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from -r ControlNetPlus/requirements.txt (line 124))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from -r ControlNetPlus/requirements.txt (line 125))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from -r ControlNetPlus/requirements.txt (line 126))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from -r ControlNetPlus/requirements.txt (line 127))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from -r ControlNetPlus/requirements.txt (line 128))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from -r ControlNetPlus/requirements.txt (line 129))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from -r ControlNetPlus/requirements.txt (line 130))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from -r ControlNetPlus/requirements.txt (line 131))
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from -r ControlNetPlus/requirements.txt (line 132))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from -r ControlNetPlus/requirements.txt (line 133))
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from -r ControlNetPlus/requirements.txt (line 134))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from -r ControlNetPlus/requirements.txt (line 135))
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from -r ControlNetPlus/requirements.txt (line 136))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from -r ControlNetPlus/requirements.txt (line 137))
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from -r ControlNetPlus/requirements.txt (line 138))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from -r ControlNetPlus/requirements.txt (line 139))
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from -r ControlNetPlus/requirements.txt (line 140))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.99 (from -r ControlNetPlus/requirements.txt (line 141))
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from -r ControlNetPlus/requirements.txt (line 142))
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from -r ControlNetPlus/requirements.txt (line 143))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: oauthlib==3.2.2 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 144)) (3.2.2)
# Collecting omegaconf==2.3.0 (from -r ControlNetPlus/requirements.txt (line 145))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting open-clip-torch==2.24.0 (from -r ControlNetPlus/requirements.txt (line 146))
#   Downloading open_clip_torch-2.24.0-py3-none-any.whl.metadata (30 kB)
# Collecting openai-clip==1.0.1 (from -r ControlNetPlus/requirements.txt (line 147))
#   Downloading openai-clip-1.0.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting opencv-python==4.9.0.80 (from -r ControlNetPlus/requirements.txt (line 148))
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opencv-python-headless==4.9.0.80 (from -r ControlNetPlus/requirements.txt (line 149))
#   Downloading opencv_python_headless-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting orjson==3.10.3 (from -r ControlNetPlus/requirements.txt (line 150))
#   Downloading orjson-3.10.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.0 MB/s eta 0:00:00
# Collecting overrides==7.7.0 (from -r ControlNetPlus/requirements.txt (line 151))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting packaging==24.0 (from -r ControlNetPlus/requirements.txt (line 152))
#   Downloading packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==2.0.3 (from -r ControlNetPlus/requirements.txt (line 153))
#   Downloading pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: pandocfilters==1.5.1 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 154)) (1.5.1)
# Collecting parso==0.8.3 (from -r ControlNetPlus/requirements.txt (line 155))
#   Downloading parso-0.8.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pexpect==4.9.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 156)) (4.9.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 157)) (0.7.5)
# Collecting pillow==10.2.0 (from -r ControlNetPlus/requirements.txt (line 158))
#   Downloading pillow-10.2.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting pkgutil_resolve_name==1.3.10 (from -r ControlNetPlus/requirements.txt (line 159))
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting platformdirs==4.2.0 (from -r ControlNetPlus/requirements.txt (line 160))
#   Downloading platformdirs-4.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting prometheus_client==0.20.0 (from -r ControlNetPlus/requirements.txt (line 161))
#   Downloading prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting prompt-toolkit==3.0.43 (from -r ControlNetPlus/requirements.txt (line 162))
#   Downloading prompt_toolkit-3.0.43-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf==4.25.3 (from -r ControlNetPlus/requirements.txt (line 163))
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting psutil==5.9.8 (from -r ControlNetPlus/requirements.txt (line 164))
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 165)) (0.7.0)
# Collecting pure-eval==0.2.2 (from -r ControlNetPlus/requirements.txt (line 166))
#   Downloading pure_eval-0.2.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: py-cpuinfo==9.0.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 167)) (9.0.0)
# Collecting pyarrow==15.0.2 (from -r ControlNetPlus/requirements.txt (line 168))
#   Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix==0.6 (from -r ControlNetPlus/requirements.txt (line 169))
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting pyasn1==0.6.0 (from -r ControlNetPlus/requirements.txt (line 170))
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting pyasn1_modules==0.4.0 (from -r ControlNetPlus/requirements.txt (line 171))
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pycparser==2.22 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 172)) (2.22)
# Collecting pydantic==2.6.4 (from -r ControlNetPlus/requirements.txt (line 173))
#   Downloading pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 kB 7.5 MB/s eta 0:00:00
# Collecting pydantic_core==2.16.3 (from -r ControlNetPlus/requirements.txt (line 174))
#   Downloading pydantic_core-2.16.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting pydub==0.25.1 (from -r ControlNetPlus/requirements.txt (line 175))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting Pygments==2.17.2 (from -r ControlNetPlus/requirements.txt (line 176))
#   Downloading pygments-2.17.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting pynvml==11.5.0 (from -r ControlNetPlus/requirements.txt (line 177))
#   Downloading pynvml-11.5.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting pyparsing==3.1.2 (from -r ControlNetPlus/requirements.txt (line 178))
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil==2.9.0.post0 (from -r ControlNetPlus/requirements.txt (line 179))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting python-json-logger==2.0.7 (from -r ControlNetPlus/requirements.txt (line 180))
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting python-multipart==0.0.9 (from -r ControlNetPlus/requirements.txt (line 181))
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting pytorch-lightning==2.2.1 (from -r ControlNetPlus/requirements.txt (line 182))
#   Downloading pytorch_lightning-2.2.1-py3-none-any.whl.metadata (21 kB)
# Collecting pytz==2024.1 (from -r ControlNetPlus/requirements.txt (line 183))
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting PyWavelets==1.4.1 (from -r ControlNetPlus/requirements.txt (line 184))
#   Downloading PyWavelets-1.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting PyYAML==6.0.1 (from -r ControlNetPlus/requirements.txt (line 185))
#   Downloading PyYAML-6.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pyzmq==25.1.2 (from -r ControlNetPlus/requirements.txt (line 186))
#   Downloading pyzmq-25.1.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting qtconsole==5.5.1 (from -r ControlNetPlus/requirements.txt (line 187))
#   Downloading qtconsole-5.5.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting QtPy==2.4.1 (from -r ControlNetPlus/requirements.txt (line 188))
#   Downloading QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Collecting referencing==0.34.0 (from -r ControlNetPlus/requirements.txt (line 189))
#   Downloading referencing-0.34.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting regex==2023.12.25 (from -r ControlNetPlus/requirements.txt (line 190))
#   Downloading regex-2023.12.25-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.3 MB/s eta 0:00:00
# Collecting requests==2.31.0 (from -r ControlNetPlus/requirements.txt (line 191))
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: requests-oauthlib==2.0.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 192)) (2.0.0)
# Collecting rfc3339-validator==0.1.4 (from -r ControlNetPlus/requirements.txt (line 193))
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator==0.1.1 (from -r ControlNetPlus/requirements.txt (line 194))
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting rich==13.7.1 (from -r ControlNetPlus/requirements.txt (line 195))
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting rpds-py==0.18.0 (from -r ControlNetPlus/requirements.txt (line 196))
#   Downloading rpds_py-0.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: rsa==4.9 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 197)) (4.9)
# Collecting ruff==0.4.6 (from -r ControlNetPlus/requirements.txt (line 198))
#   Downloading ruff-0.4.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Collecting safetensors==0.4.2 (from -r ControlNetPlus/requirements.txt (line 199))
#   Downloading safetensors-0.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting scikit-image==0.21.0 (from -r ControlNetPlus/requirements.txt (line 200))
#   Downloading scikit_image-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting scikit-learn==1.3.2 (from -r ControlNetPlus/requirements.txt (line 201))
#   Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy==1.10.1 (from -r ControlNetPlus/requirements.txt (line 202))
#   Downloading scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 5.5 MB/s eta 0:00:00
# Collecting semantic-version==2.10.0 (from -r ControlNetPlus/requirements.txt (line 203))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: Send2Trash==1.8.3 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 204)) (1.8.3)
# Requirement already satisfied: sentencepiece==0.2.0 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 205)) (0.2.0)
# Collecting sentry-sdk==1.43.0 (from -r ControlNetPlus/requirements.txt (line 206))
#   Downloading sentry_sdk-1.43.0-py2.py3-none-any.whl.metadata (9.9 kB)
# Collecting setproctitle==1.3.3 (from -r ControlNetPlus/requirements.txt (line 207))
#   Downloading setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: shellingham==1.5.4 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 208)) (1.5.4)
# Collecting six==1.16.0 (from -r ControlNetPlus/requirements.txt (line 209))
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting smmap==5.0.1 (from -r ControlNetPlus/requirements.txt (line 210))
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 211)) (1.3.1)
# Collecting soupsieve==2.5 (from -r ControlNetPlus/requirements.txt (line 212))
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting stack-data==0.6.3 (from -r ControlNetPlus/requirements.txt (line 213))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting starlette==0.37.2 (from -r ControlNetPlus/requirements.txt (line 214))
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting sympy==1.12 (from -r ControlNetPlus/requirements.txt (line 215))
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting tensorboard==2.14.0 (from -r ControlNetPlus/requirements.txt (line 216))
#   Downloading tensorboard-2.14.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 217)) (0.7.2)
# Requirement already satisfied: terminado==0.18.1 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 218)) (0.18.1)
# Collecting threadpoolctl==3.4.0 (from -r ControlNetPlus/requirements.txt (line 219))
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting tifffile==2023.7.10 (from -r ControlNetPlus/requirements.txt (line 220))
#   Downloading tifffile-2023.7.10-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken==0.6.0 (from -r ControlNetPlus/requirements.txt (line 221))
#   Downloading tiktoken-0.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting timm==0.6.7 (from -r ControlNetPlus/requirements.txt (line 222))
#   Downloading timm-0.6.7-py3-none-any.whl.metadata (33 kB)
# Collecting tinycss2==1.2.1 (from -r ControlNetPlus/requirements.txt (line 223))
#   Downloading tinycss2-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting tokenizers==0.15.2 (from -r ControlNetPlus/requirements.txt (line 224))
#   Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: toml==0.10.2 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 225)) (0.10.2)
# Collecting tomli==2.0.1 (from -r ControlNetPlus/requirements.txt (line 226))
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting tomlkit==0.12.0 (from -r ControlNetPlus/requirements.txt (line 227))
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: toolz==0.12.1 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 228)) (0.12.1)
# Collecting torch==2.0.1 (from -r ControlNetPlus/requirements.txt (line 229))
#   Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchmetrics==1.3.2 (from -r ControlNetPlus/requirements.txt (line 230))
#   Downloading torchmetrics-1.3.2-py3-none-any.whl.metadata (19 kB)
# Collecting torchsde==0.2.6 (from -r ControlNetPlus/requirements.txt (line 231))
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Collecting torchvision==0.15.2 (from -r ControlNetPlus/requirements.txt (line 232))
#   Downloading torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl.metadata (11 kB)
# Collecting tornado==6.4 (from -r ControlNetPlus/requirements.txt (line 233))
#   Downloading tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting tqdm==4.66.2 (from -r ControlNetPlus/requirements.txt (line 234))
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.6 MB/s eta 0:00:00
# Collecting traitlets==5.9.0 (from -r ControlNetPlus/requirements.txt (line 235))
#   Downloading traitlets-5.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting trampoline==0.1.2 (from -r ControlNetPlus/requirements.txt (line 236))
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Collecting transformers==4.39.1 (from -r ControlNetPlus/requirements.txt (line 237))
#   Downloading transformers-4.39.1-py3-none-any.whl.metadata (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.7 MB/s eta 0:00:00
# Collecting triton==2.0.0 (from -r ControlNetPlus/requirements.txt (line 238))
#   Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Collecting typer==0.12.3 (from -r ControlNetPlus/requirements.txt (line 239))
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Collecting types-python-dateutil==2.9.0.20240316 (from -r ControlNetPlus/requirements.txt (line 240))
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl.metadata (1.8 kB)
# Collecting typing_extensions==4.10.0 (from -r ControlNetPlus/requirements.txt (line 241))
#   Downloading typing_extensions-4.10.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tzdata==2024.1 (from -r ControlNetPlus/requirements.txt (line 242))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting uri-template==1.3.0 (from -r ControlNetPlus/requirements.txt (line 243))
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting urllib3==2.2.1 (from -r ControlNetPlus/requirements.txt (line 244))
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting uvicorn==0.29.0 (from -r ControlNetPlus/requirements.txt (line 245))
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting voluptuous==0.14.2 (from -r ControlNetPlus/requirements.txt (line 246))
#   Downloading voluptuous-0.14.2-py3-none-any.whl.metadata (20 kB)
# Collecting wandb==0.16.5 (from -r ControlNetPlus/requirements.txt (line 247))
#   Downloading wandb-0.16.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 248)) (0.2.13)
# Collecting webcolors==1.13 (from -r ControlNetPlus/requirements.txt (line 249))
#   Downloading webcolors-1.13-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.11/dist-packages (from -r ControlNetPlus/requirements.txt (line 250)) (0.5.1)
# Collecting websocket-client==1.7.0 (from -r ControlNetPlus/requirements.txt (line 251))
#   Downloading websocket_client-1.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting websockets==11.0.3 (from -r ControlNetPlus/requirements.txt (line 252))
#   Downloading websockets-11.0.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting Werkzeug==3.0.1 (from -r ControlNetPlus/requirements.txt (line 253))
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting widgetsnbextension==4.0.10 (from -r ControlNetPlus/requirements.txt (line 254))
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting xformers==0.0.22 (from -r ControlNetPlus/requirements.txt (line 255))
#   Downloading xformers-0.0.22-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting xxhash==3.4.1 (from -r ControlNetPlus/requirements.txt (line 256))
#   Downloading xxhash-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl==1.9.4 (from -r ControlNetPlus/requirements.txt (line 257))
# ...
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: mdit-py-plugins
#     Found existing installation: mdit-py-plugins 0.4.2
#     Uninstalling mdit-py-plugins-0.4.2:
#       Successfully uninstalled mdit-py-plugins-0.4.2
#   Attempting uninstall: matplotlib-inline
#     Found existing installation: matplotlib-inline 0.1.7
#     Uninstalling matplotlib-inline-0.1.7:
#       Successfully uninstalled matplotlib-inline-0.1.7
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.5
#     Uninstalling Jinja2-3.1.5:
#       Successfully uninstalled Jinja2-3.1.5
#   Attempting uninstall: importlib_metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Successfully uninstalled importlib_metadata-8.6.1
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.37.0
#     Uninstalling imageio-2.37.0:
#       Successfully uninstalled imageio-2.37.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: gitdb
#     Found existing installation: gitdb 4.0.12
#     Uninstalling gitdb-4.0.12:
#       Successfully uninstalled gitdb-4.0.12
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.1
#     Uninstalling contourpy-1.3.1:
#       Successfully uninstalled contourpy-1.3.1
#   Attempting uninstall: bleach
#     Found existing installation: bleach 6.2.0
#     Uninstalling bleach-6.2.0:
#       Successfully uninstalled bleach-6.2.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.13.3
#     Uninstalling beautifulsoup4-4.13.3:
#       Successfully uninstalled beautifulsoup4-4.13.3
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.2
#     Uninstalling aiosignal-1.3.2:
#       Successfully uninstalled aiosignal-1.3.2
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.1
#     Uninstalling typer-0.15.1:
#       Successfully uninstalled typer-0.15.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.2
#     Uninstalling scikit-image-0.25.2:
#       Successfully uninstalled scikit-image-0.25.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Uninstalling pydantic-2.10.6:
#       Successfully uninstalled pydantic-2.10.6
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: jupyter_client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jsonschema-specifications
#     Found existing installation: jsonschema-specifications 2024.10.1
#     Uninstalling jsonschema-specifications-2024.10.1:
#       Successfully uninstalled jsonschema-specifications-2024.10.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.28.1
#     Uninstalling huggingface-hub-0.28.1:
#       Successfully uninstalled huggingface-hub-0.28.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.27.0
#     Uninstalling google-auth-2.27.0:
#       Successfully uninstalled google-auth-2.27.0
#   Attempting uninstall: GitPython
#     Found existing installation: GitPython 3.1.44
#     Uninstalling GitPython-3.1.44:
#       Successfully uninstalled GitPython-3.1.44
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.12
#     Uninstalling aiohttp-3.11.12:
#       Successfully uninstalled aiohttp-3.11.12
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.19.6
#     Uninstalling wandb-0.19.6:
#       Successfully uninstalled wandb-0.19.6
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.23.0
#     Uninstalling jsonschema-4.23.0:
#       Successfully uninstalled jsonschema-4.23.0
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.32.2
#     Uninstalling diffusers-0.32.2:
#       Successfully uninstalled diffusers-0.32.2
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 2.0.4
#     Uninstalling albumentations-2.0.4:
#       Successfully uninstalled albumentations-2.0.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.49.0
#     Uninstalling transformers-4.49.0:
#       Successfully uninstalled transformers-4.49.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
#   Attempting uninstall: altair
#     Found existing installation: altair 5.5.0
#     Uninstalling altair-5.5.0:
#       Successfully uninstalled altair-5.5.0
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.10.2
#     Uninstalling nbclient-0.10.2:
#       Successfully uninstalled nbclient-0.10.2
#   Attempting uninstall: jupyter-console
#     Found existing installation: jupyter-console 6.1.0
#     Uninstalling jupyter-console-6.1.0:
#       Successfully uninstalled jupyter-console-6.1.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 7.16.6
#     Uninstalling nbconvert-7.16.6:
#       Successfully uninstalled nbconvert-7.16.6
#   Attempting uninstall: jupyter_server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
#   Attempting uninstall: nbclassic
#     Found existing installation: nbclassic 1.2.0
#     Uninstalling nbclassic-1.2.0:
#       Successfully uninstalled nbclassic-1.2.0
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.5
#     Uninstalling notebook-6.5.5:
#       Successfully uninstalled notebook-6.5.5
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu124
#     Uninstalling torchvision-0.20.1+cu124:
#       Successfully uninstalled torchvision-0.20.1+cu124
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.14
#     Uninstalling timm-1.0.14:
#       Successfully uninstalled timm-1.0.14
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.4.0
#     Uninstalling accelerate-1.4.0:
#       Successfully uninstalled accelerate-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.27.0, but you have google-auth 2.29.0 which is incompatible.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.29.4 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.12.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.0.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.4 which is incompatible.
# grpcio-status 1.62.3 requires grpcio>=1.62.3, but you have grpcio 1.62.1 which is incompatible.
# pygit2 1.17.0 requires cffi>=1.17.0, but you have cffi 1.16.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# tensorflow 2.18.0 requires tensorboard<2.19,>=2.18, but you have tensorboard 2.14.0 which is incompatible.
# peft 0.14.0 requires huggingface-hub>=0.25.0, but you have huggingface-hub 0.22.1 which is incompatible.
# google-genai 0.8.0 requires websockets<15.0dev,>=13.0, but you have websockets 11.0.3 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.4 which is incompatible.
# blosc2 3.1.1 requires numpy>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.0.3 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 2.0.3 which is incompatible.
# flask 3.1.0 requires Werkzeug>=3.1, but you have werkzeug 3.0.1 which is incompatible.
# pymc 5.20.1 requires numpy>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.39.1 which is incompatible.
# xarray 2025.1.2 requires pandas>=2.1, but you have pandas 2.0.3 which is incompatible.
# pytensor 2.27.1 requires filelock>=3.15, but you have filelock 3.13.3 which is incompatible.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.0.1 which is incompatible.
# bokeh 3.6.3 requires contourpy>=1.2, but you have contourpy 1.1.1 which is incompatible.
# openai 1.61.1 requires typing-extensions<5,>=4.11, but you have typing-extensions 4.10.0 which is incompatible.
# langchain 0.3.19 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 1.24.4 which is incompatible.
# langchain 0.3.19 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 2.6.4 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.2.0 which is incompatible.
# nx-cugraph-cu12 24.12.0 requires networkx>=3.2, but you have networkx 3.1 which is incompatible.
# Successfully installed Babel-2.14.0 GitPython-3.1.42 Jinja2-3.1.3 Markdown-3.6 MarkupSafe-2.1.5 PyWavelets-1.4.1 PyYAML-6.0.1 Pygments-2.17.2 QtPy-2.4.1 Werkzeug-3.0.1 absl-py-2.1.0 accelerate-0.28.0 aiofiles-23.2.1 aiohttp-3.9.3 aiosignal-1.3.1 albumentations-1.4.2 altair-5.3.0 annotated-types-0.6.0 antlr4-python3-runtime-4.9.3 anyio-4.3.0 appdirs-1.4.4 arrow-1.3.0 asttokens-2.4.1 async-lru-2.0.4 async-timeout-4.0.3 attrs-23.2.0 beautifulsoup4-4.12.3 bleach-6.1.0 cachetools-5.3.3 certifi-2024.2.2 cffi-1.16.0 charset-normalizer-3.3.2 click-8.1.7 cmake-3.29.0.1 comm-0.2.2 contourpy-1.1.1 controlnet-aux-0.0.9 dadaptation-3.2 datasets-2.18.0 debugpy-1.8.1 decorator-5.1.1 deepspeed-0.14.0 diffusers-0.27.2 dill-0.3.8 einops-0.7.0 exceptiongroup-1.2.0 executing-2.0.1 fastapi-0.110.2 fastjsonschema-2.19.1 ffmpy-0.3.2 filelock-3.13.3 fonttools-4.51.0 fqdn-1.5.1 frozenlist-1.4.1 fsspec-2024.2.0 ftfy-6.2.0 gitdb-4.0.11 google-auth-2.29.0 google-auth-oauthlib-1.0.0 gradio-3.41.2 gradio_client-0.5.0 grpcio-1.62.1 hjson-3.1.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.22.1 idna-3.6 imageio-2.34.0 importlib_metadata-7.1.0 importlib_resources-6.4.0 ipykernel-6.29.4 ipython-8.12.3 ipywidgets-8.1.2 isoduration-20.11.0 jedi-0.19.1 joblib-1.3.2 json5-0.9.24 jsonpointer-2.4 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.10.0 jupyter-lsp-2.2.4 jupyter_client-8.6.1 jupyter_server-2.13.0 jupyter_server_terminals-0.5.3 jupyterlab-4.1.6 jupyterlab_server-2.26.0 jupyterlab_widgets-3.0.10 jupytext-1.16.1 kiwisolver-1.4.5 lazy_loader-0.3 lightning-utilities-0.11.2 lit-18.1.2 loguru-0.7.2 matplotlib-3.7.5 matplotlib-inline-0.1.6 mdit-py-plugins-0.4.0 mistune-3.0.2 multidict-6.0.5 multiprocess-0.70.16 nbclassic-1.0.0 nbclient-0.10.0 nbconvert-7.16.3 networkx-3.1 ninja-1.11.1.1 notebook-6.5.4 numpy-1.24.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu11-8.5.0.96 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu11-10.9.0.58 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu11-10.2.10.91 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu11-11.7.4.91 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu11-2.14.3 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu11-11.7.91 nvidia-nvtx-cu12-12.1.105 omegaconf-2.3.0 open-clip-torch-2.24.0 openai-clip-1.0.1 opencv-python-4.9.0.80 opencv-python-headless-4.9.0.80 orjson-3.10.3 overrides-7.7.0 packaging-24.0 pandas-2.0.3 parso-0.8.3 pillow-10.2.0 pkgutil_resolve_name-1.3.10 platformdirs-4.2.0 prometheus_client-0.20.0 prompt-toolkit-3.0.43 protobuf-4.25.3 psutil-5.9.8 pure-eval-0.2.2 pyarrow-15.0.2 pyarrow-hotfix-0.6 pyasn1-0.6.0 pyasn1_modules-0.4.0 pydantic-2.6.4 pydantic_core-2.16.3 pydub-0.25.1 pynvml-11.5.0 pyparsing-3.1.2 python-dateutil-2.9.0.post0 python-json-logger-2.0.7 python-multipart-0.0.9 pytorch-lightning-2.2.1 pytz-2024.1 pyzmq-25.1.2 qtconsole-5.5.1 referencing-0.34.0 regex-2023.12.25 requests-2.31.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rich-13.7.1 rpds-py-0.18.0 ruff-0.4.6 safetensors-0.4.2 scikit-image-0.21.0 scikit-learn-1.3.2 scipy-1.10.1 semantic-version-2.10.0 sentry-sdk-1.43.0 setproctitle-1.3.3 six-1.16.0 smmap-5.0.1 soupsieve-2.5 stack-data-0.6.3 starlette-0.37.2 sympy-1.12 tensorboard-2.14.0 threadpoolctl-3.4.0 tifffile-2023.7.10 tiktoken-0.6.0 timm-0.6.7 tinycss2-1.2.1 tokenizers-0.15.2 tomli-2.0.1 tomlkit-0.12.0 torch-2.0.1 torchmetrics-1.3.2 torchsde-0.2.6 torchvision-0.15.2 tornado-6.4 tqdm-4.66.2 traitlets-5.9.0 trampoline-0.1.2 transformers-4.39.1 triton-2.0.0 typer-0.12.3 types-python-dateutil-2.9.0.20240316 typing_extensions-4.10.0 tzdata-2024.1 uri-template-1.3.0 urllib3-2.2.1 uvicorn-0.29.0 voluptuous-0.14.2 wandb-0.16.5 webcolors-1.13 ...

# %%
# !git clone https://huggingface.co/xinsir/controlnet-union-sdxl-1.0
# Out:
# Cloning into 'controlnet-union-sdxl-1.0'...
# remote: Enumerating objects: 177, done.
# remote: Total 177 (delta 0), reused 0 (delta 0), pack-reused 177 (from 1)
# Receiving objects: 100% (177/177), 37.19 MiB | 43.87 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Filtering content: 100% (4/4), 4.68 GiB | 63.96 MiB/s, done.

# %%
# %cd ControlNetPlus
# !python controlnet_union_test_openpose.py
# Out:
# /content/ControlNetPlus
# 2025-02-23 02:09:31.504225: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740276571.526254   18127 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740276571.533073   18127 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Traceback (most recent call last):
#   File "/content/ControlNetPlus/controlnet_union_test_openpose.py", line 8, in <module>
#     from controlnet_aux import OpenposeDetector
# ModuleNotFoundError: No module named 'controlnet_aux'

# %% [markdown]
# Controlnet官方的例子

# %%
# !git clone https://github.com/lllyasviel/ControlNet.git
# Out:
# Cloning into 'ControlNet'...
# remote: Enumerating objects: 1356, done.
# remote: Total 1356 (delta 0), reused 0 (delta 0), pack-reused 1356 (from 1)
# Receiving objects: 100% (1356/1356), 122.40 MiB | 42.41 MiB/s, done.
# Resolving deltas: 100% (596/596), done.

# %%
# !git clone https://huggingface.co/lllyasviel/ControlNet ControlNet1/
# Out:
# Cloning into 'ControlNet1'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 52 (delta 16), reused 52 (delta 16), pack-reused 0 (from 0)
# Unpacking objects: 100% (52/52), 7.05 KiB | 722.00 KiB/s, done.
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
#
# Exiting because of "interrupt" signal.
# ^C

# %%
# !unzip /content/ControlNet1/training/fill50k.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fill50k/target/5499.png
#   inflating: fill50k/target/55.png
#   inflating: fill50k/target/550.png
#   inflating: fill50k/target/5500.png
#   inflating: fill50k/target/5501.png
#   inflating: fill50k/target/5502.png
#   inflating: fill50k/target/5503.png
#   inflating: fill50k/target/5504.png
#   inflating: fill50k/target/5505.png
#   inflating: fill50k/target/5506.png
#   inflating: fill50k/target/5507.png
#   inflating: fill50k/target/5508.png
#   inflating: fill50k/target/5509.png
#   inflating: fill50k/target/551.png
#   inflating: fill50k/target/5510.png
#   inflating: fill50k/target/5511.png
#   inflating: fill50k/target/5512.png
#   inflating: fill50k/target/5513.png
#   inflating: fill50k/target/5514.png
#   inflating: fill50k/target/5515.png
#   inflating: fill50k/target/5516.png
#   inflating: fill50k/target/5517.png
#   inflating: fill50k/target/5518.png
#   inflating: fill50k/target/5519.png
#   inflating: fill50k/target/552.png
#   inflating: fill50k/target/5520.png
#   inflating: fill50k/target/5521.png
#   inflating: fill50k/target/5522.png
#   inflating: fill50k/target/5523.png
#   inflating: fill50k/target/5524.png
#   inflating: fill50k/target/5525.png
#   inflating: fill50k/target/5526.png
#   inflating: fill50k/target/5527.png
#   inflating: fill50k/target/5528.png
#   inflating: fill50k/target/5529.png
#   inflating: fill50k/target/553.png
#   inflating: fill50k/target/5530.png
#   inflating: fill50k/target/5531.png
#   inflating: fill50k/target/5532.png
#   inflating: fill50k/target/5533.png
#   inflating: fill50k/target/5534.png
#   inflating: fill50k/target/5535.png
#   inflating: fill50k/target/5536.png
#   inflating: fill50k/target/5537.png
#   inflating: fill50k/target/5538.png
#   inflating: fill50k/target/5539.png
#   inflating: fill50k/target/554.png
#   inflating: fill50k/target/5540.png
#   inflating: fill50k/target/5541.png
#   inflating: fill50k/target/5542.png
#   inflating: fill50k/target/5543.png
#   inflating: fill50k/target/5544.png
#   inflating: fill50k/target/5545.png
#   inflating: fill50k/target/5546.png
#   inflating: fill50k/target/5547.png
#   inflating: fill50k/target/5548.png
#   inflating: fill50k/target/5549.png
#   inflating: fill50k/target/555.png
#   inflating: fill50k/target/5550.png
#   inflating: fill50k/target/5551.png
#   inflating: fill50k/target/5552.png
#   inflating: fill50k/target/5553.png
#   inflating: fill50k/target/5554.png
#   inflating: fill50k/target/5555.png
#   inflating: fill50k/target/5556.png
#   inflating: fill50k/target/5557.png
#   inflating: fill50k/target/9979.png
#   inflating: fill50k/target/998.png
#   inflating: fill50k/target/9980.png
#   inflating: fill50k/target/9981.png
#   inflating: fill50k/target/9982.png
#   inflating: fill50k/target/9983.png
#   inflating: fill50k/target/9984.png
#   inflating: fill50k/target/9985.png
#   inflating: fill50k/target/9986.png
#   inflating: fill50k/target/9987.png
#   inflating: fill50k/target/9988.png
#   inflating: fill50k/target/9989.png
#   inflating: fill50k/target/999.png
#   inflating: fill50k/target/9990.png
#   inflating: fill50k/target/9991.png
#   inflating: fill50k/target/9992.png
#   inflating: fill50k/target/9993.png
#   inflating: fill50k/target/9994.png
#   inflating: fill50k/target/9995.png
#   inflating: fill50k/target/9996.png
#   inflating: fill50k/target/9997.png
#   inflating: fill50k/target/9998.png
#   inflating: fill50k/target/9999.png

# %%
# !git clone https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main
# Out:
# Cloning into 'main'...
# remote: Entry not found
# fatal: repository 'https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/' not found

# %%
import json
import cv2
import numpy as np

from torch.utils.data import Dataset


class MyDataset(Dataset):
    def __init__(self):
        self.data = []
        with open('./training/fill50k/prompt.json', 'rt') as f:
            for line in f:
                self.data.append(json.loads(line))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]

        source_filename = item['source']
        target_filename = item['target']
        prompt = item['prompt']

        source = cv2.imread('./training/fill50k/' + source_filename)
        target = cv2.imread('./training/fill50k/' + target_filename)

        # Do not forget that OpenCV read images in BGR order.
        source = cv2.cvtColor(source, cv2.COLOR_BGR2RGB)
        target = cv2.cvtColor(target, cv2.COLOR_BGR2RGB)

        # Normalize source images to [0, 1].
        source = source.astype(np.float32) / 255.0

        # Normalize target images to [-1, 1].
        target = (target.astype(np.float32) / 127.5) - 1.0

        return dict(jpg=target, txt=prompt, hint=source)

# %%
from tutorial_dataset import MyDataset

dataset = MyDataset()
print(len(dataset))

item = dataset[1234]
jpg = item['jpg']
txt = item['txt']
hint = item['hint']
print(txt)
print(jpg.shape)
print(hint.shape)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DownUpBlock(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels):
        super(DownUpBlock, self).__init__()
        # 下采样部分：卷积 + 最大池化
        self.conv_down = nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        # 上采样部分：转置卷积 + 卷积
        self.upconv = nn.ConvTranspose2d(mid_channels, mid_channels, kernel_size=2, stride=2)
        self.conv_up = nn.Conv2d(mid_channels * 2, out_channels, kernel_size=3, padding=1)

    def forward(self, x):
        # 下采样
        x1 = F.relu(self.conv_down(x))
        x_down = self.pool(x1)
        # 上采样
        x_up = F.relu(self.upconv(x_down))
        # 如果需要，可以在这里将上采样结果与下采样前的特征（x1）做拼接（skip connection）
        # 注意确保尺寸匹配，如果尺寸不匹配可能需要裁剪
        x_cat = torch.cat([x_up, x1], dim=1)
        x_out = F.relu(self.conv_up(x_cat))
        return x_out

# 测试
if __name__ == '__main__':
    x = torch.randn(1, 3, 64, 64)  # 输入图像尺寸为 64x64
    block = DownUpBlock(in_channels=3, mid_channels=16, out_channels=8)
    y = block(x)
    print("DownUpBlock输出尺寸:", y.shape)
# Out:
# DownUpBlock输出尺寸: torch.Size([1, 8, 64, 64])
